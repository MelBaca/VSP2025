# %%
import pandas as pd
import src.DataProcessing.read_data as rd

ruta = '../data/TABLAS ORDINARIOS CCTROLEBUS Vs11 20-10-2023-IMPR.xlsx'
hoja_c4_c6 = 'CONSOL C4-C6-L-V'
base = rd.lectura_tablas_c4_c6(ruta,hoja_c4_c6)
base = rd.transformacion_a_minutos(base)
# base = base[base['CIRCUITO']=='C4'].reset_index(drop=True).drop("ORD",axis=1).reset_index()
# base.columns = ["ORD","COD. OP.","CIRCUITO","SALIDA","LLEGADA"]
# base['ORD'] = base['ORD']+1
base.head()
# Out:
#    ORD COD. OP. CIRCUITO  SALIDA  LLEGADA
# 0    1       1Q       C4   300.0    408.0
# 1    2      21Q       C6   306.0    356.0
# 2    3       2Q       C4   307.0    415.0
# 3    4       3Q       C4   314.0    422.0
# 4    5      22Q       C6   316.0    366.0

# %%
ruta = 'Datasets/New_tables/LUNES_VIERNES_C4_C6.xlsx'
hoja_c4_c6 = 'C4_C6'
base = rd.tablas_ordinarios_c4_c6_v2(ruta, hoja_c4_c6)
base = base[['ORD','COD. OP.','CIRCUITO','HORA_SALIDA','HORA_LLEGADA']].reset_index(drop=True).drop("ORD",axis=1).reset_index()
base.columns =['ORD','COD. OP.','CIRCUITO','SALIDA','LLEGADA']
base['ORD'] = base['ORD']+1
base.head()
# Out:
# /Users/luis/Desktop/UNIVERSIDAD/PASANTIA_optimizacion/Researching_Model_Desing/src/DataProcessing/read_data.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quitumbe_sur_norte['HORA_SALIDA'] = quitumbe_sur_norte['HORA SALIDA ǪUITUMBE'].apply(hora_a_minutos)
# /Users/luis/Desktop/UNIVERSIDAD/PASANTIA_optimizacion/Researching_Model_Desing/src/DataProcessing/read_data.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quitumbe_sur_norte.dropna(subset='ORD',inplace=True)
# /Users/luis/Desktop/UNIVERSIDAD/PASANTIA_optimizacion/Researching_Model_Desing/src/DataProcessing/read_data.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quitumbe_sur_norte['HORA_LLEGADA'] = quitumbe_sur_norte['HORA LLEGADA ǪUITUMBE'].apply(hora_a_minutos)
#    ORD COD. OP. CIRCUITO  SALIDA  LLEGADA
# 0    1       1Ǫ       C4   300.0    408.0
# 1    2       2Ǫ       C4   308.0    416.0
# 2    3       3Ǫ       C4   316.0    424.0
# 3    4       4Ǫ       C4   324.0    432.0
# 4    5       5Ǫ       C4   332.0    440.0

# %%
delta = 25 # Parametro de tolerancia
P = 40 # Parametro que indica longitud de pause

# Parametros para controlar tiempito minimo y máximo de espera
l1 = 2
u1 = 25

# Parámetros para controlar tiempo mínimo y máximo de descanso
l2 = P - delta
u2 = P + delta 

# Parametros

break1 = 240
break2 = 670#720
break3 = 960
totalHorasTrabajadas =  1440

M_P = 5
M_T = 1440

b = base['LLEGADA']
b = {key+1:value for key,value in b.to_dict().items()}

a = base['SALIDA']
a = {key+1:value for key,value in a.to_dict().items()}

base = rd.creacion_arcos_A1_A2(base,l1,u1,l2,u2)
base
# Out:
#      ORD COD. OP. CIRCUITO  SALIDA  LLEGADA  \
# 0      1       1Q       C4   300.0    408.0
# 1      2      21Q       C6   306.0    356.0
# 2      3       2Q       C4   307.0    415.0
# 3      4       3Q       C4   314.0    422.0
# 4      5      22Q       C6   316.0    366.0
# ..   ...      ...      ...     ...      ...
# 217  218       4Q       C6  1294.0   1344.0
# 218  219       5Q       C6  1301.0   1351.0
# 219  220       6Q       C6  1309.0   1359.0
# 220  221       7Q       C6  1317.0   1367.0
# 221  222       8Q       C6  1325.0   1375.0
#
#                                            Arcos-Costo  \
# 0    [(32.0, 5.0), (33.0, 8.0), (34.0, 13.0), (35.0...
# 1    [(16.0, 0.0), (17.0, 4.0), (18.0, 9.0), (19.0,...
# 2    [(33.0, 1.0), (34.0, 6.0), (35.0, 11.0), (36.0...
# 3    [(35.0, 4.0), (36.0, 9.0), (37.0, 14.0), (38.0...
# 4    [(19.0, 0.0), (20.0, 4.0), (21.0, 9.0), (22.0,...
# ..                                                 ...
# 217                                                 []
# 218                                                 []
# 219                                                 []
# 220                                                 []
# 221                                                 []
#
#                                         Arcos-Costo A1  \
# 0    [(32.0, 5.0), (33.0, 8.0), (34.0, 13.0), (35.0...
# 1    [(17.0, 4.0), (18.0, 9.0), (19.0, 10.0), (20.0...
# 2    [(34.0, 6.0), (35.0, 11.0), (36.0, 16.0), (37....
# 3    [(35.0, 4.0), (36.0, 9.0), (37.0, 14.0), (38.0...
# 4    [(20.0, 4.0), (21.0, 9.0), (22.0, 10.0), (23.0...
# ..                                                 ...
# 217                                                 []
# 218                                                 []
# 219                                                 []
# 220                                                 []
# 221                                                 []
#
#                                         Arcos-Costo A2
# 0    [(35.0, 18.0), (36.0, 23.0), (37.0, 28.0), (38...
# 1    [(21.0, 19.0), (22.0, 20.0), (23.0, 24.0), (24...
# 2    [(36.0, 16.0), (37.0, 21.0), (38.0, 26.0), (39...
# 3    [(38.0, 19.0), (39.0, 29.0), (40.0, 29.0), (41...
# 4    [(24.0, 19.0), (25.0, 20.0), (26.0, 24.0), (27...
# ..                                                 ...
# 217                                                 []
# 218                                                 []
# 219                                                 []
# 220                                                 []
# 221                                                 []
#
# [222 rows x 8 columns]

# %%
import numpy as np

# Unidades
M = len(base['COD. OP.'].unique()) 
print('M: ',M)

# Viajes 
N = base['ORD'].unique()
print('N: ',len(N))
N0 = np.insert(N, 0, 0)

# Creación del diccionario de costos
costos = {}
costos_A1 = {}
costos_A2 = {}
costos_inicio_fin = {}
for index,row in base.iterrows():
    costos_arcos_A1 = {(row['ORD'],int(i[0])):i[1] for i in row['Arcos-Costo A1']}
    costos_A1.update(costos_arcos_A1)
    
    costos_arcos_A2 = {(row['ORD'],int(i[0])):i[1] for i in row['Arcos-Costo A2']}
    costos_A2.update(costos_arcos_A2)
    
    costos_arcos = {(row['ORD'],int(i[0])):i[1] for i in row['Arcos-Costo']}
    costos.update(costos_arcos)
    
    costos_inicio_fin[(0,row['ORD'])] = 0
    costos_inicio_fin[(row['ORD'],len(N)+1)] = 0
    
costos.update(costos_inicio_fin)

arcos_A1 = costos_A1.keys()
arcos_A2 = costos_A2.keys()
arcos_unidades_A1 = []
arcos_unidades_A2 = []
arcos_unidades_inicio_fin = []

arcos_unidad_i_A1 = [(arco[0],arco[1],1) for arco in arcos_A1 if arco[0]!=0 and arco[1]!=(len(N)+1)]
arcos_unidades_A1 += arcos_unidad_i_A1

arcos_unidad_i_A2 = [(arco[0],arco[1],1) for arco in arcos_A2 if arco[0]!=0 and arco[1]!=(len(N)+1)]
arcos_unidades_A2 += arcos_unidad_i_A2

arcos_unidades_inicio = [(0,row['ORD'],1) for index,row in base.iterrows()]
arcos_unidades_fin = [(row['ORD'],len(N)+1,1) for index,row in base.iterrows()]
arcos_unidades_inicio_fin = arcos_unidades_inicio + arcos_unidades_fin    
    
print('A1',len(arcos_unidades_A1))
print('A2',len(arcos_unidades_A2))
print('Inicio-Fin',len(arcos_unidades_inicio_fin))
print('Inicio',len(arcos_unidades_inicio))
print('Fin',len(arcos_unidades_fin))

arcos = arcos_unidades_A1+arcos_unidades_A2+arcos_unidades_inicio_fin
arcos = list(set(arcos))

indices_A1 = list(set([elemento for tupla in arcos_unidades_A1 for elemento in tupla]))

indices_A2 = list(set([elemento for tupla in arcos_unidades_A2 for elemento in tupla]))
# Out:
# M:  26
# N:  222
# A1 1075
# A2 2210
# Inicio-Fin 444
# Inicio 222
# Fin 222

# %%
base[base['ORD']==103]
# Out:
#      ORD COD. OP. CIRCUITO  SALIDA  LLEGADA  \
# 102  103      20Ǫ       C6   402.0    454.0
#
#                                            Arcos-Costo  \
# 102  [(21.0, 7.0), (22.0, 17.0), (23.0, 27.0), (24....
#
#                                         Arcos-Costo A1  \
# 102  [(21.0, 7.0), (22.0, 17.0), (110.0, 12.0), (11...
#
#                                         Arcos-Costo A2
# 102  [(25.0, 47.0), (26.0, 57.0), (113.0, 48.0), (1...

# %%
costos[(103,25)]
# Out:
# np.float64(47.0)

# %%
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt

capacidad = M
# Lists to store the evolution of key metrics
gap_list = []
time_list = []
lower_bound_list = []
upper_bound_list = []

# Define the callback function
def my_callback(model, where):
    if where == gp.GRB.Callback.MIP:
        # Check if there's a feasible solution (best objective value exists)
        best_obj = model.cbGet(gp.GRB.Callback.MIP_OBJBST)
        best_bound = model.cbGet(gp.GRB.Callback.MIP_OBJBND)

        if best_obj < gp.GRB.INFINITY:
            # Compute the GAP only if best_obj is valid
            gap = abs(best_obj - best_bound) / (abs(best_obj) + 1e-10)  # Add a small value to avoid division by zero

            # Capture the time during the optimization
            current_time = model.cbGet(gp.GRB.Callback.RUNTIME)

            # Store the values
            gap_list.append(gap)
            lower_bound_list.append(best_bound)
            upper_bound_list.append(best_obj)
            time_list.append(current_time)


# Define and optimize your Gurobi model
model = gp.Model()


m3 = gp.Model('Asignacion-Flota-V1')
# Terminar al alcanzar un Gap del 10%
m3.Params.MIPGap = 0.10
m3.setParam('OutputFlag', 1)
# Enfocar estrategia en mejorar la cota dual
m3.Params.MIPFocus = 3
m3.Params.NoRelHeurTime = 30

# Fijar generación muy agresiva de cortes
m3.Params.Cuts = 1

# Terminar luego de 180 segundos
m3.Params.TimeLimit = 300

x = m3.addVars(arcos,vtype=GRB.BINARY,name='x')
z = m3.addVars(N,vtype=GRB.BINARY,name='z')


T = m3.addVars(N,vtype=GRB.INTEGER,name='T',ub=1440)
PV = m3.addVars(N,vtype=GRB.INTEGER,name='P',lb=0,ub=2)

#T[0].ub = 0
#PV[0].ub = 0

y0 = m3.addVars(N,vtype=GRB.BINARY,name='y1')
y1 = m3.addVars(N,vtype=GRB.BINARY,name='y2')
y2 = m3.addVars(N,vtype=GRB.BINARY,name='y3')


m3.setParam('LogFile', 'gurobi.log')

m3.setObjective(gp.quicksum(costos[i,j]*x[i,j,k] for i,j,k in arcos)+ 1000*z.sum('*') ,GRB.MINIMIZE)

m3.addConstrs((T[j] >= (b[j]-a[j]) - M_T*(1-x[i,j,k]) for i,j,k in arcos_unidades_inicio),name='T_lower_inicio')
m3.addConstrs((T[j] <=  (b[j]-a[j]) + M_T*(1-x[i,j,k]) for i,j,k in arcos_unidades_inicio),name='T_upper_inico ')

m3.addConstrs((PV[j]<= M_P*(1-x[i,j,k]) for i,j,k in arcos_unidades_inicio),name = 'P_upper_inicio')
m3.addConstrs((PV[j]>= - M_P*(1-x[i,j,k]) for i,j,k in arcos_unidades_inicio),name = 'P_lower_inicio')

m3.addConstrs((x.sum(n,'*','*') == 1 - z[n] for n in N), name=f"Constraints")
m3.addConstrs((x.sum('*',i,1)-x.sum(i,'*',1)==0 for i in N ),name=f'Conservacion')
m3.addConstr(x.sum(0,'*',1) <= capacidad, name=f"Capacidades")


m3.addConstrs((T[j] >= T[i] + (b[j]-b[i]) - M_T*(1-x[i,j,k]) for i,j,k in arcos_unidades_A1 ),name='T_upper_A1')
m3.addConstrs((T[j] <= T[i] + (b[j]-b[i]) + M_T*(1-x[i,j,k]) for i,j,k in arcos_unidades_A1 ),name='T_lower_A1')

m3.addConstrs((PV[j] >= PV[i] - M_P*(1-x[i,j,k]) for i,j,k in arcos_unidades_A1 ),name='P_upper_A1')
m3.addConstrs((PV[j] <= PV[i] + M_P*(1-x[i,j,k]) for i,j,k in arcos_unidades_A1 ),name='P_lower_A1')


m3.addConstrs((T[j] >= T[i] + (b[j]-b[i]) - M_T*(1-x[i,j,k]) for i,j,k in arcos_unidades_A2 ),name='T_upper_A2')
m3.addConstrs((T[j] <= T[i] + (b[j]-b[i]) + M_T*(1-x[i,j,k]) for i,j,k in arcos_unidades_A2 ),name='T_lower_A2')

m3.addConstrs((PV[j] >= PV[i] + 1 - M_P*(1-x[i,j,k]) for i,j,k in arcos_unidades_A2 ),name='P_upper_A2')
m3.addConstrs((PV[j] <= PV[i] + 1 + M_P*(1-x[i,j,k]) for i,j,k in arcos_unidades_A2 ),name='P_lower_A2')


m3.addConstrs((T[i]<= break1 - 0.5*P + delta+M_T*(1-y0[i]) for i in N), name = 'N1_Restriccion' )
m3.addConstrs((T[i] - (b[i]-a[i]) >= break1 + 0.5*P - delta-M_T*(1-y1[i]) for i in N), name = 'N2_Restriccion' )
m3.addConstrs((T[i]<= break2 - 0.5*P + delta+M_T*(1-y1[i]) for i in N), name = 'N3_Restriccion' )
m3.addConstrs((T[i] - (b[i]-a[i]) >= break2 + 0.5*P - delta-M_T*(1-y2[i]) for i in N), name = 'N4_Restriccion' )
m3.addConstrs((T[i]<= break3 + M_T*(1-y2[i]) for i in N), name = 'N4_Restriccion' )

m3.addConstrs((y0[n]+y1[n]+y2[n]==1 for n in N ),name='Aux1')
m3.addConstrs((y1[n]+2*y2[n]==PV[n] for n in N ),name='Aux2')


m3.write('Modelo.lp')


m3.optimize(my_callback)

# 16minutos ---> GAP: 72,5% | Cota Inf: 9557 | Best Value: 34711
# Out:
# Set parameter MIPGap to value 0.1
# Set parameter MIPFocus to value 3
# Set parameter NoRelHeurTime to value 30
# Set parameter Cuts to value 1
# Set parameter TimeLimit to value 300
# Set parameter LogFile to value "gurobi.log"
# Warning: constraint name "T_upper_inico [0,1,1]" has a space
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Max
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 16027 rows, 4572 columns and 54246 nonzeros
# Model fingerprint: 0x375b1277
# Variable types: 0 continuous, 4572 integer (4128 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 222000.00000
# Presolve removed 5323 rows and 707 columns
# Presolve time: 0.14s
# Presolved: 10704 rows, 3865 columns, 37675 nonzeros
# Variable types: 0 continuous, 3865 integer (3422 binary)
# Found heuristic solution: objective 199000.00000
# Starting NoRel heuristic
# Found heuristic solution: objective 170355.00000
# Found heuristic solution: objective 163430.00000
# Found heuristic solution: objective 161456.00000
# Found heuristic solution: objective 160459.00000
# Found heuristic solution: objective 158469.00000
# Found heuristic solution: objective 119041.00000
# Found heuristic solution: objective 118094.00000
# Found heuristic solution: objective 118073.00000
# Found heuristic solution: objective 118039.00000
# Found heuristic solution: objective 116139.00000
# Found heuristic solution: objective 116105.00000
# Found heuristic solution: objective 115168.00000
# Found heuristic solution: objective 114150.00000
# Found heuristic solution: objective 113154.00000
# Found heuristic solution: objective 110221.00000
# Found heuristic solution: objective 110204.00000
# Found heuristic solution: objective 109215.00000
# Found heuristic solution: objective 108228.00000
# Found heuristic solution: objective 107221.00000
# Found heuristic solution: objective 106237.00000
# Found heuristic solution: objective 106230.00000
# Found heuristic solution: objective 106223.00000
# Found heuristic solution: objective 105203.00000
# Found heuristic solution: objective 104265.00000
# Found heuristic solution: objective 103222.00000
# Found heuristic solution: objective 102286.00000
# Found heuristic solution: objective 102261.00000
# Found heuristic solution: objective 99340.000000
# Found heuristic solution: objective 99325.000000
# Found heuristic solution: objective 98398.000000
# Found heuristic solution: objective 94438.000000
# Found heuristic solution: objective 90452.000000
# Found heuristic solution: objective 89525.000000
# Found heuristic solution: objective 84604.000000
# Found heuristic solution: objective 82577.000000
# Found heuristic solution: objective 78645.000000
# Found heuristic solution: objective 77633.000000
# Found heuristic solution: objective 74695.000000
# Found heuristic solution: objective 74635.000000
# Found heuristic solution: objective 70718.000000
# Found heuristic solution: objective 70664.000000
# Found heuristic solution: objective 66754.000000
# Found heuristic solution: objective 64778.000000
# Found heuristic solution: objective 63837.000000
# Found heuristic solution: objective 63769.000000
# Found heuristic solution: objective 61934.000000
# Found heuristic solution: objective 61903.000000
# Found heuristic solution: objective 58976.000000
# Found heuristic solution: objective 58969.000000
# Found heuristic solution: objective 57976.000000
# Found heuristic solution: objective 57004.000000
# Found heuristic solution: objective 56020.000000
# Found heuristic solution: objective 53112.000000
# Found heuristic solution: objective 53086.000000
# Found heuristic solution: objective 52054.000000
# Found heuristic solution: objective 51108.000000
# Found heuristic solution: objective 50079.000000
# Found heuristic solution: objective 50058.000000
# Found heuristic solution: objective 49995.000000
# Found heuristic solution: objective 49086.000000
# Found heuristic solution: objective 49076.000000
# Found heuristic solution: objective 48088.000000
# Found heuristic solution: objective 48078.000000
# Found heuristic solution: objective 48073.000000
# Found heuristic solution: objective 48063.000000
# Found heuristic solution: objective 47134.000000
# Found heuristic solution: objective 46138.000000
# Found heuristic solution: objective 45105.000000
# Found heuristic solution: objective 44162.000000
# Found heuristic solution: objective 44147.000000
# Elapsed time for NoRel heuristic: 5s (best bound 3463)
# Found heuristic solution: objective 44140.000000
# Found heuristic solution: objective 44132.000000
# Found heuristic solution: objective 44125.000000
# Found heuristic solution: objective 44111.000000
# Found heuristic solution: objective 43166.000000
# Found heuristic solution: objective 43088.000000
# Found heuristic solution: objective 42141.000000
# Found heuristic solution: objective 40157.000000
# Found heuristic solution: objective 40153.000000
# Found heuristic solution: objective 40150.000000
# Found heuristic solution: objective 40146.000000
# Found heuristic solution: objective 40143.000000
# Found heuristic solution: objective 40124.000000
# Found heuristic solution: objective 40115.000000
# Found heuristic solution: objective 39120.000000
# Found heuristic solution: objective 38194.000000
# Found heuristic solution: objective 37247.000000
# Found heuristic solution: objective 36259.000000
# Found heuristic solution: objective 36237.000000
# Found heuristic solution: objective 35322.000000
# Found heuristic solution: objective 35273.000000
# Found heuristic solution: objective 34317.000000
# Elapsed time for NoRel heuristic: 10s (best bound 3463)
# Found heuristic solution: objective 34310.000000
# Found heuristic solution: objective 34289.000000
# Found heuristic solution: objective 34282.000000
# Found heuristic solution: objective 34276.000000
# Found heuristic solution: objective 34226.000000
# Found heuristic solution: objective 34204.000000
# Found heuristic solution: objective 33252.000000
# Found heuristic solution: objective 32257.000000
# Found heuristic solution: objective 31296.000000
# Found heuristic solution: objective 31290.000000
# Found heuristic solution: objective 29357.000000
# Found heuristic solution: objective 29319.000000
# Found heuristic solution: objective 29305.000000
# Found heuristic solution: objective 29303.000000
# Found heuristic solution: objective 29297.000000
# Found heuristic solution: objective 28351.000000
# Found heuristic solution: objective 28339.000000
# Elapsed time for NoRel heuristic: 16s (best bound 3463)
# Found heuristic solution: objective 28332.000000
# Found heuristic solution: objective 28317.000000
# Found heuristic solution: objective 28290.000000
# Found heuristic solution: objective 28282.000000
# Found heuristic solution: objective 28270.000000
# Found heuristic solution: objective 28263.000000
# Elapsed time for NoRel heuristic: 22s (best bound 3463)
# Found heuristic solution: objective 27291.000000
# Found heuristic solution: objective 27271.000000
# Found heuristic solution: objective 27266.000000
# Found heuristic solution: objective 27264.000000
# Found heuristic solution: objective 27261.000000
# Found heuristic solution: objective 27247.000000
# Found heuristic solution: objective 27244.000000
# Elapsed time for NoRel heuristic: 28s (best bound 3463)
# Found heuristic solution: objective 27225.000000
# Root relaxation presolved: 10704 rows, 3865 columns, 37675 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.3661000e+04   2.778719e+03   0.000000e+00     30s
#     3816    3.5080000e+03   0.000000e+00   0.000000e+00     31s
#     3816    3.5080000e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 3.508000e+03, 3816 iterations, 0.16 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3508.00000    0  197 27225.0000 3508.00000  87.1%     -   30s
#      0     0 3508.00000    0  556 27225.0000 3508.00000  87.1%     -   30s
#      0     0 3508.00000    0  539 27225.0000 3508.00000  87.1%     -   31s
#      0     0 3508.00000    0  200 27225.0000 3508.00000  87.1%     -   31s
#      0     0 3508.00000    0  326 27225.0000 3508.00000  87.1%     -   31s
#      0     0 3508.00000    0  195 27225.0000 3508.00000  87.1%     -   32s
#      0     0 3508.00000    0  258 27225.0000 3508.00000  87.1%     -   32s
#      0     0 3508.00000    0  189 27225.0000 3508.00000  87.1%     -   33s
#      0     0 3508.00000    0  279 27225.0000 3508.00000  87.1%     -   33s
#      0     0 3508.00000    0  225 27225.0000 3508.00000  87.1%     -   33s
#      0     0 3508.00000    0  173 27225.0000 3508.00000  87.1%     -   33s
#      0     2 3508.00000    0  173 27225.0000 3508.00000  87.1%     -   33s
#    115    21 infeasible   13      27225.0000 3508.00000  87.1%   179   35s
# H  171    25                    27220.000000 3508.00000  87.1%   135   35s
#    472   192 3557.43257   25  398 27220.0000 3557.43257  86.9%  75.5   40s
#   1931  1322 6395.00000   47  301 27220.0000 6395.00000  76.5%  75.8   45s
#   1949  1334 6401.78236   24  320 27220.0000 6401.78236  76.5%  75.1   50s
# H 1986  1301                    27216.000000 6410.41176  76.4%  95.1   51s
# H 2028  1260                    26289.000000 6410.87889  75.6%  98.6   51s
# H 2066  1227                    25293.000000 6413.15677  74.6%  98.5   53s
#   2152  1275 7452.00390   26  507 25293.0000 6417.00390  74.6%   107   57s
# H 2157  1216                    25287.000000 6418.00390  74.6%   108   57s
# H 2161  1160                    24336.000000 6418.00390  73.6%   108   57s
#   2264  1233 7280.30865   30  498 24336.0000 6422.00389  73.6%   117   60s
# H 2266  1181                    23367.000000 6422.00389  72.5%   117   60s
#   3209  1825 7418.00000   25  343 23367.0000 6424.00000  72.5%   139   65s
#   4414  2721 7306.41061   28  649 23367.0000 6430.88039  72.5%   152   70s
#
# Interrupt request received
#
# Cutting planes:
#   Learned: 25
#   Gomory: 19
#   Lift-and-project: 4
#   Cover: 300
#   Implied bound: 26
#   MIR: 119
#   Mixing: 17
#   StrongCG: 12
#   Flow cover: 404
#   GUB cover: 40
#   Zero half: 30
#   RLT: 22
#   Relax-and-lift: 67
#   BQP: 1
#
# Explored 6323 nodes (972953 simplex iterations) in 74.87 seconds (79.41 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 23367 24336 25287 ... 27247
#
# Solve interrupted
# Best objective 2.336700000000e+04, best bound 6.451000000000e+03, gap 72.3927%
#
# User-callback calls 33000, time in user-callback 0.21 sec

# %%
# Plot the results in two subplots within the same figure
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 5))  # 2 rows, 1 column

# Plot 1: Lower and Upper Bound
ax1.plot(time_list[5:], lower_bound_list[5:], label='Lower Bound', color='blue')
ax1.plot(time_list[5:], upper_bound_list[5:], label='Upper Bound', color='red')
ax1.set_xlabel('Time (seconds)')
ax1.set_ylabel('Bound Value')
ax1.set_title('Lower and Upper Bound Evolution Over Time')
ax1.legend()
ax1.grid(True)

# Plot 2: GAP
ax2.plot(time_list[5:], gap_list[5:], label='GAP', color='green')
ax2.set_xlabel('Time (seconds)')
ax2.set_ylabel('GAP')
ax2.set_title('GAP Evolution Over Time')
ax2.legend()
ax2.grid(True)

# Show the plots
plt.tight_layout()  # Adjusts spacing between plots
plt.show()

# %%
def generar_sublistas(tuplas,tuplas_iniciales):
    sublistas = []
    while tuplas_iniciales:
        sublista = []
        actual = tuplas_iniciales.pop(0)
        sublista.append(actual)
        
        # Buscar conexiones hacia adelante
        while True:
            found = False
            for i, t in enumerate(tuplas):
                if t[0] == actual[1]:
                    sublista.append(t)
                    actual = t
                    tuplas.pop(i)
                    found = True
                    break
            if not found:
                break
        
        sublistas.append(sublista)
    
    return sublistas


def hora_a_minutos(n):
    hora = str(n).split(':')
    if len(hora) == 3:
        return float(hora[0])*60 + float(hora[1])+ float(hora[2])/100
    if len(hora) == 2:
        return float(hora[0])*60 + float(hora[1])



vx = m3.getAttr('x', x)
solucion = {}
tuplas = []
tuplas_iniciales = []
contador = 1
for tupla,valor in vx.items():
    if valor >= 0.95 :
        tuplas.append(tupla)
    if valor >= 0.95 and tupla[0]==0:
        tuplas_iniciales.append(tupla)
        
resultados = generar_sublistas(tuplas,tuplas_iniciales)

for i in resultados:
    if len(i)>1:
        solucion[contador] = {0:0}
        
        solucion[contador][0]= i[0][0]
        for k in i:
            solucion[contador][k[0]]= k[1]
        contador +=1
        
print("---------------------- SOLUCION ----------------------")
print(solucion)

asignacion = pd.DataFrame()
for k in range(1,M+1):   
    nodo = 0    
    ord = []
    tiempo_anden = []
    while nodo != len(N)+1:
        if k == 2:
            print(costos[nodo,solucion[k][nodo]])
        tiempo_anden.append(costos[nodo,solucion[k][nodo]])
        ord.append(solucion[k][nodo])
        nodo = solucion[k][nodo]
    if k == 2:
        print(tiempo_anden)
    a = base[list(base.columns[0:1]) + list(base.columns[3:5]) + list(base.columns[9:10])]
    a = a[a['ORD'].isin(ord)].reset_index(drop=True)
    if k == 2:
        print(a)
    a['Tiempo en anden'] = pd.Series(tiempo_anden)
    
    a['UNIDAD ASIGNADA'] = k
    if k == 2:
        print(a)
    asignacion = pd.concat([asignacion,a])
asignacion = asignacion.sort_values(by='SALIDA')
print('---------------------- ASIGNACION FINAL ----------------------')
print(asignacion.head(10).to_markdown(index=False),'\n')
# Out:
# ---------------------- SOLUCION ----------------------
# {1: {0: 2, 2: 18, 18: 56, 56: 70, 70: 83, 83: 116, 116: 223}, 2: {0: 16, 16: 33, 33: 44, 44: 76, 76: 107, 107: 138, 138: 168, 168: 197, 197: 206, 206: 214, 214: 223}, 3: {0: 3, 3: 34, 34: 61, 61: 89, 89: 106, 106: 120, 120: 158, 158: 187, 187: 223}, 4: {0: 17, 17: 43, 43: 74, 74: 105, 105: 135, 135: 146, 146: 178, 178: 223}, 5: {0: 47, 47: 59, 59: 73, 73: 109, 109: 137, 137: 148, 148: 160, 160: 173, 173: 223}, 6: {0: 20, 20: 46, 46: 79, 79: 110, 110: 139, 139: 175, 175: 200, 200: 208, 208: 216, 216: 223}, 7: {0: 50, 50: 63, 63: 77, 77: 92, 92: 113, 113: 129, 129: 142, 142: 155, 155: 185, 185: 223}, 8: {0: 1, 1: 32, 32: 65, 65: 80, 80: 94, 94: 111, 111: 125, 125: 157, 157: 170, 170: 198, 198: 223}, 9: {0: 4, 4: 35, 35: 45, 45: 68, 68: 97, 97: 112, 112: 223}, 10: {0: 37, 37: 48, 48: 75, 75: 95, 95: 127, 127: 140, 140: 152, 152: 190, 190: 209, 209: 217, 217: 223}, 11: {0: 51, 51: 78, 78: 119, 119: 132, 132: 156, 156: 188, 188: 223}, 12: {0: 114, 114: 141, 141: 174, 174: 189, 189: 207, 207: 215, 215: 222, 222: 223}, 13: {0: 28, 28: 40, 40: 49, 49: 88, 88: 122, 122: 147, 147: 180, 180: 223}, 14: {0: 42, 42: 53, 53: 67, 67: 82, 82: 102, 102: 134, 134: 159, 159: 196, 196: 205, 205: 213, 213: 221, 221: 223}, 15: {0: 13, 13: 31, 31: 41, 41: 71, 71: 101, 101: 131, 131: 143, 143: 176, 176: 192, 192: 223}, 16: {0: 30, 30: 52, 52: 90, 90: 123, 123: 149, 149: 181, 181: 204, 204: 212, 212: 220, 220: 223}, 17: {0: 7, 7: 25, 25: 38, 38: 66, 66: 96, 96: 128, 128: 163, 163: 177, 177: 201, 201: 223}, 18: {0: 10, 10: 29, 29: 62, 62: 91, 91: 124, 124: 223}, 19: {0: 54, 54: 81, 81: 118, 118: 144, 144: 169, 169: 184, 184: 223}, 20: {0: 5, 5: 22, 22: 36, 36: 64, 64: 93, 93: 223}, 21: {0: 57, 57: 84, 84: 100, 100: 121, 121: 136, 136: 161, 161: 191, 191: 199, 199: 223}, 22: {0: 87, 87: 103, 103: 117, 117: 150, 150: 179, 179: 194, 194: 202, 202: 210, 210: 218, 218: 223}, 23: {0: 11, 11: 39, 39: 69, 69: 99, 99: 130, 130: 154, 154: 171, 171: 186, 186: 223}, 24: {0: 104, 104: 133, 133: 145, 145: 166, 166: 182, 182: 195, 195: 203, 203: 211, 211: 219, 219: 223}, 25: {0: 85, 85: 115, 115: 153, 153: 183, 183: 223}, 26: {0: 58, 58: 86, 86: 126, 126: 151, 151: 162, 162: 193, 193: 223}}
# 0
# 10.0
# 13.0
# 31.0
# 5.0
# 10.0
# 37.0
# 8.0
# 11.0
# 6.0
# 0
# [0, np.float64(10.0), np.float64(13.0), np.float64(31.0), np.float64(5.0), np.float64(10.0), np.float64(37.0), np.float64(8.0), np.float64(11.0), np.float64(6.0), 0]
#    ORD  SALIDA  LLEGADA
# 0   16   356.0    406.0
# 1   33   416.0    468.0
# 2   44   481.0    596.0
# 3   76   627.0    742.0
# 4  107   747.0    862.0
# 5  138   872.0    987.0
# 6  168  1024.0   1139.0
# 7  197  1147.0   1199.0
# 8  206  1210.0   1260.0
# 9  214  1266.0   1316.0
#    ORD  SALIDA  LLEGADA  Tiempo en anden  UNIDAD ASIGNADA
# 0   16   356.0    406.0              0.0                2
# 1   33   416.0    468.0             10.0                2
# 2   44   481.0    596.0             13.0                2
# 3   76   627.0    742.0             31.0                2
# 4  107   747.0    862.0              5.0                2
# 5  138   872.0    987.0             10.0                2
# 6  168  1024.0   1139.0             37.0                2
# 7  197  1147.0   1199.0              8.0                2
# 8  206  1210.0   1260.0             11.0                2
# 9  214  1266.0   1316.0              6.0                2
# ---------------------- ASIGNACION FINAL ----------------------
# |   ORD |   SALIDA |   LLEGADA |   Tiempo en anden |   UNIDAD ASIGNADA |
# |------:|---------:|----------:|------------------:|------------------:|
# |     1 |      300 |       408 |                 0 |                 8 |
# |     2 |      306 |       356 |                 0 |                 1 |
# |     3 |      307 |       415 |                 0 |                 3 |
# |     4 |      314 |       422 |                 0 |                 9 |
# |     5 |      316 |       366 |                 0 |                20 |
# |     7 |      326 |       376 |                 0 |                17 |
# |    10 |      336 |       386 |                 0 |                18 |
# |    11 |      340 |       448 |                 0 |                23 |
# |    13 |      346 |       396 |                 0 |                15 |
# |    16 |      356 |       406 |                 0 |                 2 |

# %%
costos[(46,73)]
# Out:
# np.float64(121.0)

# %%
unidad = 2

print(f'---------------------- ASIGNACION UNIDAD {unidad} ----------------------')

resultado_individual = asignacion[asignacion['UNIDAD ASIGNADA']==unidad]
print(resultado_individual.to_markdown(index=False),'\n')

vT = m3.getAttr('x', T)
vPV = m3.getAttr('x',PV)
vY0 = m3.getAttr('x',y0)
vY1 = m3.getAttr('x',y1)
vY2 = m3.getAttr('x',y2)

solucion = {}
tuplas = []
contador = 1

print(f'---------------------- VARIABLES MODELO ----------------------')

for i in resultado_individual['ORD'].to_list():
    print(f"Nodo {i}, T: {vT[i]}, P: {vPV[i]}, y0: {vY0[i]}, y1: {vY1[i]}, y2: {vY2[i]}")
# Out:
# ---------------------- ASIGNACION UNIDAD 2 ----------------------
# |   ORD |   SALIDA |   LLEGADA |   Tiempo en anden |   UNIDAD ASIGNADA |
# |------:|---------:|----------:|------------------:|------------------:|
# |    16 |      356 |       406 |                 0 |                 2 |
# |    33 |      416 |       468 |                10 |                 2 |
# |    44 |      481 |       596 |                13 |                 2 |
# |    76 |      627 |       742 |                31 |                 2 |
# |   107 |      747 |       862 |                 5 |                 2 |
# |   138 |      872 |       987 |                10 |                 2 |
# |   168 |     1024 |      1139 |                37 |                 2 |
# |   197 |     1147 |      1199 |                 8 |                 2 |
# |   206 |     1210 |      1260 |                11 |                 2 |
# |   214 |     1266 |      1316 |                 6 |                 2 |
#
# ---------------------- VARIABLES MODELO ----------------------
# Nodo 16, T: 50.0, P: -0.0, y0: 1.0, y1: -0.0, y2: -0.0
# Nodo 33, T: 112.0, P: -0.0, y0: 1.0, y1: -0.0, y2: -0.0
# Nodo 44, T: 240.0, P: -0.0, y0: 1.0, y1: -0.0, y2: -0.0
# Nodo 76, T: 386.0, P: 1.0, y0: -0.0, y1: 1.0, y2: -0.0
# Nodo 107, T: 506.0, P: 1.0, y0: -0.0, y1: 1.0, y2: -0.0
# Nodo 138, T: 631.0, P: 1.0, y0: -0.0, y1: 1.0, y2: -0.0
# Nodo 168, T: 783.0, P: 2.0, y0: -0.0, y1: -0.0, y2: 1.0
# Nodo 197, T: 843.0, P: 2.0, y0: -0.0, y1: -0.0, y2: 1.0
# Nodo 206, T: 904.0, P: 2.0, y0: -0.0, y1: -0.0, y2: 1.0
# Nodo 214, T: 960.0, P: 2.0, y0: -0.0, y1: -0.0, y2: 1.0

# %%
base[base['ORD']==108]
# Out:
#      ORD COD. OP. CIRCUITO  SALIDA  LLEGADA  \
# 107  108      17Ǫ       C6   442.0    494.0
#
#                                            Arcos-Costo  \
# 107  [(25.0, 7.0), (26.0, 17.0), (27.0, 27.0), (28....
#
#                                         Arcos-Costo A1  \
# 107  [(25.0, 7.0), (26.0, 17.0), (113.0, 8.0), (114...
#
#                                         Arcos-Costo A2
# 107  [(26.0, 17.0), (27.0, 27.0), (28.0, 37.0), (29...

# %%
import matplotlib.pyplot as plt

asignacion['TIEMPO_VIAJE'] = asignacion['LLEGADA'] - asignacion['SALIDA']

# Valor umbral para cambiar de color
valor_umbral = u1

# Obtener las unidades únicas
unidades = asignacion['UNIDAD ASIGNADA'].unique()
unidades.sort()



# Crear un subgráfico por cada unidad
fig, axs = plt.subplots(len(unidades), 1, figsize=(10, len(unidades)*1/1.15), sharex=True)  # Ajustar el tamaño del gráfico

# Valores para las líneas verticales

lineas_verticales_exacto = [break1,break2,break3]
lineas_verticales = [break1-P/2, break1+P/2, 480, break2-P/2, break2+P/2]

for i, unidad in enumerate(unidades):
    asignacion_unidad = asignacion[asignacion['UNIDAD ASIGNADA'] == unidad]
    
    Type = []
    Time = []
    Colors = []
    for j, row in asignacion_unidad.iterrows():
        if not np.isnan(row['Tiempo en anden']):
            Type.append('A1')
            Time.append(row['Tiempo en anden'])
            # Asignar color según el valor del tiempo en andén
            if row['Tiempo en anden'] <= valor_umbral:
                Colors.append('orange')
            else:
                Colors.append('skyblue')
        Type.append('A2')
        Time.append(row['TIEMPO_VIAJE'])
        Colors.append('lightgreen')  # Color fijo para A2
    
    data = pd.DataFrame({
        "Type": Type,
        "Time": Time,
        "Colors": Colors
    })
    
    left = 0
    bar_height = 0.3  # Ajustar el ancho de las barras
    for idx, row in data.iterrows():
        axs[i].barh(y=0, width=row['Time'], left=left, color=row['Colors'], height=bar_height)
        left += row['Time']
    
    # Añadir el texto al final de la barra
    total_time = left  # La longitud total de la barra es 'left' después del bucle
    axs[i].text(left + 0.5, 0, f'{total_time:.2f}', va='center', fontsize=9)  # Ajusta 0.5 para dar espacio al texto
    
    axs[i].set_yticks([])
    axs[i].set_title(f'Unidad {unidad}', fontsize=10)

    # Añadir líneas verticales rojas en los valores especificados
    for x_value in lineas_verticales:
        axs[i].axvline(x=x_value, color='red', linestyle='--', linewidth=2)
    for x_value in lineas_verticales_exacto:
        axs[i].axvline(x=x_value, color='green', linestyle='--', linewidth=2)

# Etiquetas comunes
fig.text(0.5, 0.04, 'Tiempo', ha='center')
fig.suptitle('Representación de tiempo por ruta y unidades', fontsize=16)

plt.tight_layout(rect=[0, 0.05, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt

asignacion['TIEMPO_VIAJE'] = asignacion['LLEGADA'] - asignacion['SALIDA']

# Valor umbral para cambiar de color
valor_umbral = u1

# Obtener las unidades únicas
unidades = asignacion['UNIDAD ASIGNADA'].unique()

# Crear un subgráfico por cada unidad
fig, axs = plt.subplots(len(unidades), 1, figsize=(10, len(unidades)*1/1.15), sharex=True)  # Ajustar el tamaño del gráfico

# Valores para las líneas verticales

lineas_verticales_exacto = [break1,break2,break3]
lineas_verticales = [break1-P/2, break1+P/2, 480, break2-P/2, break2+P/2]

for i, unidad in enumerate(unidades):
    asignacion_unidad = asignacion[asignacion['UNIDAD ASIGNADA'] == unidad]
    
    Type = []
    Time = []
    Colors = []
    for j, row in asignacion_unidad.iterrows():
        if not np.isnan(row['Tiempo en anden']):
            Type.append('A1')
            Time.append(row['Tiempo en anden'])
            # Asignar color según el valor del tiempo en andén
            if row['Tiempo en anden'] <= valor_umbral:
                Colors.append('orange')
            else:
                Colors.append('skyblue')
        Type.append('A2')
        Time.append(row['TIEMPO_VIAJE'])
        Colors.append('lightgreen')  # Color fijo para A2
    
    data = pd.DataFrame({
        "Type": Type,
        "Time": Time,
        "Colors": Colors
    })
    
    left = 0
    bar_height = 0.3  # Ajustar el ancho de las barras
    for idx, row in data.iterrows():
        axs[i].barh(y=0, width=row['Time'], left=left, color=row['Colors'], height=bar_height)
        left += row['Time']
    
    # Añadir el texto al final de la barra
    total_time = left  # La longitud total de la barra es 'left' después del bucle
    axs[i].text(left + 0.5, 0, f'{total_time:.2f}', va='center', fontsize=9)  # Ajusta 0.5 para dar espacio al texto
    
    axs[i].set_yticks([])
    axs[i].set_title(f'Unidad {unidad}', fontsize=10)

    # Añadir líneas verticales rojas en los valores especificados
    for x_value in lineas_verticales:
        axs[i].axvline(x=x_value, color='red', linestyle='--', linewidth=2)
    for x_value in lineas_verticales_exacto:
        axs[i].axvline(x=x_value, color='green', linestyle='--', linewidth=2)

# Etiquetas comunes
fig.text(0.5, 0.04, 'Tiempo', ha='center')
fig.suptitle('Representación de tiempo por ruta y unidades', fontsize=16)

plt.tight_layout(rect=[0, 0.05, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt

asignacion['TIEMPO_VIAJE'] = asignacion['LLEGADA'] - asignacion['SALIDA']

# Valor umbral para cambiar de color
valor_umbral = u1

# Obtener las unidades únicas
unidades = asignacion['UNIDAD ASIGNADA'].unique()

# Crear un subgráfico por cada unidad
fig, axs = plt.subplots(len(unidades), 1, figsize=(10, len(unidades)*1/1.15), sharex=True)  # Ajustar el tamaño del gráfico

# Valores para las líneas verticales

lineas_verticales_exacto = [break1,break2,break3]
lineas_verticales = [break1-P/2, break1+P/2, 480, break2-P/2, break2+P/2]

for i, unidad in enumerate(unidades):
    asignacion_unidad = asignacion[asignacion['UNIDAD ASIGNADA'] == unidad]
    
    Type = []
    Time = []
    Colors = []
    for j, row in asignacion_unidad.iterrows():
        if not np.isnan(row['Tiempo en anden']):
            Type.append('A1')
            Time.append(row['Tiempo en anden'])
            # Asignar color según el valor del tiempo en andén
            if row['Tiempo en anden'] <= valor_umbral:
                Colors.append('orange')
            else:
                Colors.append('skyblue')
        Type.append('A2')
        Time.append(row['TIEMPO_VIAJE'])
        Colors.append('lightgreen')  # Color fijo para A2
    
    data = pd.DataFrame({
        "Type": Type,
        "Time": Time,
        "Colors": Colors
    })
    
    left = 0
    bar_height = 0.3  # Ajustar el ancho de las barras
    for idx, row in data.iterrows():
        axs[i].barh(y=0, width=row['Time'], left=left, color=row['Colors'], height=bar_height)
        left += row['Time']
    
    # Añadir el texto al final de la barra
    total_time = left  # La longitud total de la barra es 'left' después del bucle
    axs[i].text(left + 0.5, 0, f'{total_time:.2f}', va='center', fontsize=9)  # Ajusta 0.5 para dar espacio al texto
    
    axs[i].set_yticks([])
    axs[i].set_title(f'Unidad {unidad}', fontsize=10)

    # Añadir líneas verticales rojas en los valores especificados
    for x_value in lineas_verticales:
        axs[i].axvline(x=x_value, color='red', linestyle='--', linewidth=2)
    for x_value in lineas_verticales_exacto:
        axs[i].axvline(x=x_value, color='green', linestyle='--', linewidth=2)

# Etiquetas comunes
fig.text(0.5, 0.04, 'Tiempo', ha='center')
fig.suptitle('Representación de tiempo por ruta y unidades', fontsize=16)

plt.tight_layout(rect=[0, 0.05, 1, 0.95])
plt.show()
